# %%
matplotlib inline

# %%
import DataPipeline as dp
import pylab as plt
import matplotlib.pyplot as p
from mpl_toolkits.mplot3d import Axes3D

#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')

fp='10-25_Data/Numbers/rockpatch2.csv'

data_dict=dp.ProcessData(fp)

# %%
plt.figure(1)
print len(data_dict.keys())

for key in data_dict.keys():
    
    scan_obj=data_dict[key]
    left_cleaned, right_cleaned=scan_obj.GetCleanedData()

#print left_cleaned

    leftx,lefty,leftz=zip(*left_cleaned)
    rightx,righty,rightz=zip(*right_cleaned)

    
    plt.scatter(lefty, leftz)
    
plt.show()
# Out:
# 308

# %%
fp='10-25_Data/Numbers/grass3.csv'

data_dict2=dp.ProcessData(fp)

# %%
plt.figure(2)
print len(data_dict2.keys())

for key in data_dict2.keys():
    
    scan_obj=data_dict2[key]
    left_cleaned, right_cleaned=scan_obj.GetCleanedData()

#print left_cleaned

    leftx,lefty,leftz=zip(*left_cleaned)
    rightx,righty,rightz=zip(*right_cleaned)

    
    plt.scatter(lefty, leftz)
    
plt.show()
# Out:
# 307

# %%
scan_obj=data_dict2[0]
left_cleaned, right_cleaned=scan_obj.GetCleanedData()

leftx,lefty,leftz=zip(*left_cleaned)
rightx,righty,rightz=zip(*right_cleaned)

    
plt.scatter(lefty, leftz)
    
plt.show()
